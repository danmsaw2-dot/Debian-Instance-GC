# %% [markdown]
# <a href="https://colab.research.google.com/github/danmsaw2-dot/Debian-Instance-GC/blob/main/EnigMano_Debian_Instance_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ⚡ EnigMano Colab Instance
#
# ![Python](https://img.shields.io/badge/Python-3.10-blue?style=for-the-badge&logo=python&logoColor=white)
# ![Colab](https://img.shields.io/badge/Platform-Colab-red?style=for-the-badge&logo=googlecolab&logoColor=white)
# ![Ngrok](https://img.shields.io/badge/Ngrok-Required-purple?style=for-the-badge&logo=ngrok&logoColor=white)
#
# ---
#
# **EnigMano Colab Quick Setup** is a tiny, yet powerful script to instantly deploy your EnigMano Colab instance.
# It handles GPU utilities, sets up Ngrok for tunneling, and launches the main Colab environment with a single command.
#
# ---
#
# ## 🔥 Features
#
# - ✅ Installs **GPUtil** for GPU detection and monitoring
# - ✅ Requests **Ngrok auth token** and configures it automatically
# - ✅ Downloads and runs the **main EnigMano Colab setup** script
# - ✅ Fully automated, minimal setup required
# - ✅ Works seamlessly on **Google Colab** or
# ---
#
# ## 🔐 Prerequisites
#
# * Google account with **Colab access**
# * **Ngrok account** for authentication and tunneling
# * Internet access to fetch the main setup script
#
# ---
#
# ## ⚠️ Notes & Tips
#
# * Keep your **Ngrok token private** 🔒
# * Use in trusted environments only
# * Ensure runtime is set to GPU for maximum performance
#
# ---
#
# ## 🙌 Credits
#
# Built & maintained by **SHAHZAIB-YT** — enabling fast, secure, and tactical cloud deployment. 🔋
#
# ---
#
# Ready to launch your EnigMano Colab instance with a single click? Enter your Ngrok token and deploy! ⚡🛡️

# %%
# Install GPUtil
# !pip install -q gputil

import os

# Ask user for Ngrok auth token
ngrok_token = input("Enter your Ngrok auth token: ")
os.environ["NGROK_AUTH_TOKEN"] = ngrok_token

# Run the main setup script
# !curl -sL https://bit.ly/EnigMano-Colab-Instance | python3 -
# Out:
#   Preparing metadata (setup.py) ... done
# ...
